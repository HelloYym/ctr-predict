# %%
import os
import zipfile
import time
import pickle
import gc

import pandas as pd
import numpy as np
from tqdm import tqdm

from utils import load_pickle, dump_pickle, get_feature_value, feature_spearmanr, feature_target_spearmanr, addCrossFeature, calibration
from utils import raw_data_path, feature_data_path, cache_pkl_path, analyse

# %%
all_data_path = feature_data_path + 'all_data_all_features_until_25.pkl'
all_data = load_pickle(all_data_path)

target = 'is_trade'

features = load_pickle(feature_data_path + 'features_0420.pkl')

# features = list(all_data.columns)
# features.remove('is_trade')
# features.remove('instance_id')

len(features)
# Out:
# 273

# %% [markdown]
# # 原生接口

# %%
from sklearn.metrics import log_loss
from lightgbm import LGBMClassifier
import lightgbm as lgb


train_data = all_data[(all_data.day >= 19) & (all_data.day <= 23)]
test_data = all_data[all_data.day == 24]

lgb_train_data = lgb.Dataset(
    train_data[features], label=train_data[target], feature_name=features)
lgb_test_data = lgb_train_data.create_valid(
    test_data[features], label=test_data[target])


param = {'application': 'binary',
         'metric': 'binary_logloss',
         
         'num_iterations': 950,
         'learning_rate': 0.02,
         
         'max_depth': 5,
         'num_leaves': 18,
         
         'min_data_in_leaf': 100,
         'min_sum_hessian_in_leaf': 0.1,
         'min_gain_to_split': 0.1,
         
         'feature_fraction': 1.0,
         'bagging_fraction': 0.7,
         'bagging_freq': 1,
         
         'lambda_l2': 0.02,
         'max_bin': 63,
         
#          'early_stopping_round': 200,
         
         'device': 'gpu',
         'gpu_use_dp': False,
         }

# param = {'application': 'binary',
#          'metric': 'binary_logloss',
         
#          'num_iterations': 1100,
#          'learning_rate': 0.02,
         
#          'max_depth': 4,
#          'num_leaves': 20,
#          'min_data_in_leaf': 200,
         
#          'feature_fraction': 1.0,
#          'bagging_fraction': 0.7,
#          'bagging_freq': 1,
         
#          'lambda_l2': 10,
#          'max_bin': 63,
         
#          'early_stopping_round': 100,
         
#          'device': 'gpu',
#          'gpu_use_dp': False,
#          }

valid_sets = [lgb_train_data, lgb_test_data]

bst = lgb.train(param, lgb_train_data, valid_sets=valid_sets, verbose_eval=20,)

loss_train = log_loss(train_data[target], bst.predict(train_data[features]))
loss_test = log_loss(test_data[target], bst.predict(test_data[features]))

loss_train, loss_test
# Out:
# /home/user02/miniconda3/envs/gluon/lib/python3.6/site-packages/lightgbm/engine.py:99: UserWarning: Found `num_iterations` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [20]	training's binary_logloss: 0.428191	valid_1's binary_logloss: 0.427083
# [40]	training's binary_logloss: 0.288081	valid_1's binary_logloss: 0.286078
# [60]	training's binary_logloss: 0.207227	valid_1's binary_logloss: 0.20444
# [80]	training's binary_logloss: 0.158799	valid_1's binary_logloss: 0.155336
# [100]	training's binary_logloss: 0.129386	valid_1's binary_logloss: 0.125328
# [120]	training's binary_logloss: 0.111507	valid_1's binary_logloss: 0.10698
# [140]	training's binary_logloss: 0.100712	valid_1's binary_logloss: 0.0957904
# [160]	training's binary_logloss: 0.0942328	valid_1's binary_logloss: 0.088998
# [180]	training's binary_logloss: 0.0903608	valid_1's binary_logloss: 0.0849333
# [200]	training's binary_logloss: 0.088027	valid_1's binary_logloss: 0.0825407
# [220]	training's binary_logloss: 0.0865708	valid_1's binary_logloss: 0.0810731
# [240]	training's binary_logloss: 0.0856173	valid_1's binary_logloss: 0.080178
# [260]	training's binary_logloss: 0.0849153	valid_1's binary_logloss: 0.079556
# [280]	training's binary_logloss: 0.0843908	valid_1's binary_logloss: 0.0791627
# [300]	training's binary_logloss: 0.0839483	valid_1's binary_logloss: 0.0788862
# [320]	training's binary_logloss: 0.0835636	valid_1's binary_logloss: 0.078694
# [340]	training's binary_logloss: 0.08321	valid_1's binary_logloss: 0.0785463
# [360]	training's binary_logloss: 0.0828794	valid_1's binary_logloss: 0.0784363
# [380]	training's binary_logloss: 0.0825495	valid_1's binary_logloss: 0.078333
# [400]	training's binary_logloss: 0.0822497	valid_1's binary_logloss: 0.0782628
# [420]	training's binary_logloss: 0.0819596	valid_1's binary_logloss: 0.0782169
# [440]	training's binary_logloss: 0.0816893	valid_1's binary_logloss: 0.0781782
# [460]	training's binary_logloss: 0.0814185	valid_1's binary_logloss: 0.0781421
# [480]	training's binary_logloss: 0.0811552	valid_1's binary_logloss: 0.0781117
# [500]	training's binary_logloss: 0.0809121	valid_1's binary_logloss: 0.0780965
# [520]	training's binary_logloss: 0.080671	valid_1's binary_logloss: 0.0780712
# [540]	training's binary_logloss: 0.0804139	valid_1's binary_logloss: 0.0780425
# [560]	training's binary_logloss: 0.0801876	valid_1's binary_logloss: 0.0780209
# [580]	training's binary_logloss: 0.0799344	valid_1's binary_logloss: 0.0780075
# [600]	training's binary_logloss: 0.0796963	valid_1's binary_logloss: 0.0780002
# [620]	training's binary_logloss: 0.0794545	valid_1's binary_logloss: 0.0779771
# [640]	training's binary_logloss: 0.0792356	valid_1's binary_logloss: 0.0779879
# [660]	training's binary_logloss: 0.0790171	valid_1's binary_logloss: 0.0779819
# [680]	training's binary_logloss: 0.0787901	valid_1's binary_logloss: 0.0779817
# [700]	training's binary_logloss: 0.0785823	valid_1's binary_logloss: 0.0779778
# [720]	training's binary_logloss: 0.0783522	valid_1's binary_logloss: 0.0779685
# [740]	training's binary_logloss: 0.0781479	valid_1's binary_logloss: 0.0779518
# [760]	training's binary_logloss: 0.0779323	valid_1's binary_logloss: 0.0779334
# [780]	training's binary_logloss: 0.0777287	valid_1's binary_logloss: 0.0779204
# [800]	training's binary_logloss: 0.0775227	valid_1's binary_logloss: 0.0779049
# [820]	training's binary_logloss: 0.07732	valid_1's binary_logloss: 0.0779012
# [840]	training's binary_logloss: 0.0771223	valid_1's binary_logloss: 0.0778954
# [860]	training's binary_logloss: 0.0769272	valid_1's binary_logloss: 0.0778961
# [880]	training's binary_logloss: 0.0767142	valid_1's binary_logloss: 0.0778709
# [900]	training's binary_logloss: 0.0765197	valid_1's binary_logloss: 0.077878
# [920]	training's binary_logloss: 0.076323	valid_1's binary_logloss: 0.0778813
# [940]	training's binary_logloss: 0.076132	valid_1's binary_logloss: 0.0778887
# (0.076035256431205928, 0.077890141922122957)

# %%
test_data['predicted_score'] = bst.predict(test_data[features])

test_data[['instance_id', 'predicted_score']].to_csv(
    'combination/day23—features-273-depth-5-with_25.txt', index=False, sep=' ')
# Out:
# /home/user02/miniconda3/envs/gluon/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
online_best_predict = pd.read_csv("combination/online_best_8438.txt", sep=' ')['predicted_score']

online_8442_predict = pd.read_csv("combination/online-8442-features-273-with_25.txt", sep=' ')['predicted_score']

depth5_predict = pd.read_csv("combination/features-273-depth-5-with_25.txt", sep=' ')['predicted_score']

qwc_with_25 = pd.read_csv("combination/qwc_with_25.txt", sep=' ')['predicted_score']


test_predict = bst.predict(test_data[features])

total_predict = online_best_predict * 0.4 + depth5_predict * 0.6
loss_test = log_loss(test_data[target], total_predict)
print(loss_test)

# a = 100
# b = None

# for i in range(11):
#     for j in range(i+1):
        
#         w1 = 0.1 * (i - j)
#         w2 = 0.1 * i - w1
#         w3 = 1.0 - w1 - w2
# #         total_predict = test_predict * w1 + online_best_predict * w2 + depth5_predict * w3
#         total_predict = depth5_predict * w1 + online_best_predict * w2
#         loss_test = log_loss(test_data[target], total_predict)
        
#         if loss_test < a:
#             a = loss_test
#             b = (w1,w2)
        
# print(a)
# print(b)
# Out:
# 0.0777953384278

# %%
importance = pd.DataFrame(bst.feature_importance())
importance.columns = ['importance_20']
features = pd.DataFrame(features)
features.columns = ['features_20']
pd.set_option('max_rows',500)
merge = features.join(importance)
merge = merge.sort_values(by=['importance_20'], ascending=False).reset_index()
merge
# Out:
#      index                                     features_20  importance_20
# 0       92                            time_gap_after_total            377
# 1      160                              item_id_smooth_CTR            293
# 2       88                                  time_gap_after            266
# 3       20                             shop_score_delivery            254
# 4      169                              shop_id_smooth_CTR            240
# 5      178      user_age_level_item_price_level_smooth_CTR            228
# 6      263                  user_age_level_hour_smooth_CTR            166
# 7       12                                      context_id            162
# 8      262                  user_gender_id_hour_smooth_CTR            158
# 9       11                                 user_star_level            149
# 10      24                                          minute            146
# 11     261                                 hour_smooth_CTR            144
# 12     119        user_category2_label_last_click_interval            144
# 13     163                      category2_label_smooth_CTR            132
# 14     172               user_gender_id_item_id_smooth_CTR            132
# 15     175               user_age_level_item_id_smooth_CTR            132
# 16      93                         user_item_id_click_rank            130
# 17     165                     item_sales_level_smooth_CTR            127
# 18      90                   user_click_interval_mean_hour            123
# 19       4                                item_sales_level            118
# 20     264              user_occupation_id_hour_smooth_CTR            118
# 21     157                       user_age_level_smooth_CTR            118
# 22     177               user_age_level_shop_id_smooth_CTR            117
# 23     174               user_gender_id_shop_id_smooth_CTR            115
# 24     181           user_occupation_id_shop_id_smooth_CTR            112
# 25     173         user_gender_id_item_brand_id_smooth_CTR            109
# 26       7                                         user_id            107
# 27     161                        item_brand_id_smooth_CTR            107
# 28     162                         item_city_id_smooth_CTR            103
# 29     196           shop_id_user_occupation_id_click_rate             99
# 30      23                                            hour             98
# 31     183     user_star_level_item_price_level_smooth_CTR             95
# 32      30                             item_property_list4             94
# 33     180     user_occupation_id_item_brand_id_smooth_CTR             94
# 34      19                              shop_score_service             94
# 35     176         user_age_level_item_brand_id_smooth_CTR             94
# 36     159                      user_star_level_smooth_CTR             93
# 37     220                      item_sales_level_click_day             88
# 38      13                               context_timestamp             87
# 39      96                         item_id_time_gap_before             84
# 40     223                       context_page_id_click_day             83
# 41      87                                 time_gap_before             80
# 42     122            user_category2_label_click_true_rank             78
# 43     198               item_id_user_gender_id_click_rate             78
# 44      58                     user_item_id_click_day_mean             77
# 45       0                                         item_id             77
# 46     241                            shop_id_click_hour_x             76
# 47     179           user_occupation_id_item_id_smooth_CTR             75
# 48     148   user_category2_label_first_click_interval_day             74
# 49     166                 item_collected_level_smooth_CTR             74
# 50     168                      context_page_id_smooth_CTR             74
# 51     235                    category2_label_click_hour_x             72
# 52     118       user_category2_label_first_click_interval             71
# 53     150             category2_label_time_gap_before_day             71
# 54     217                          item_city_id_click_day             69
# 55     204     item_brand_id_user_occupation_id_click_rate             69
# 56     182  user_occupation_id_item_price_level_smooth_CTR             67
# 57     216                         item_brand_id_click_day             66
# 58     194               shop_id_user_gender_id_click_rate             66
# 59     237                   item_sales_level_click_hour_x             65
# 60     209     item_price_level_user_star_level_click_rate             65
# 61      31                             item_property_list5             65
# 62      17                       shop_review_positive_rate             64
# 63      32                             item_property_list6             64
# 64      21                          shop_score_description             63
# 65     200           item_id_user_occupation_id_click_rate             62
# 66     218                       category2_label_click_day             62
# 67     248                    user_star_level_click_hour_y             62
# 68      15                                         shop_id             62
# 69     197              shop_id_user_star_level_click_rate             61
# 70     205        item_brand_id_user_star_level_click_rate             60
# 71     233                      item_brand_id_click_hour_x             60
# 72     170                shop_review_num_level_smooth_CTR             60
# 73     126                     item_id_time_gap_before_day             59
# 74     155                              user_id_smooth_CTR             59
# 75     214                       user_star_level_click_day             58
# 76     254                   item_sales_level_click_hour_y             57
# 77     236                   item_price_level_click_hour_x             57
# 78      33                             item_property_list7             56
# 79     201              item_id_user_star_level_click_rate             55
# 80     171                      shop_star_level_smooth_CTR             55
# 81     260                    shop_star_level_click_hour_y             53
# 82      28                             item_property_list2             53
# 83     121                  category2_label_time_gap_after             53
# 84     247                     user_gender_id_click_hour_y             53
# 85     251                       item_city_id_click_hour_y             52
# 86     234                       item_city_id_click_hour_x             51
# 87      81                           shop_id_click_day_min             50
# 88     238               item_collected_level_click_hour_x             50
# 89     100         user_item_brand_id_first_click_interval             49
# 90     124           user_item_id_first_click_interval_day             49
# 91      29                             item_property_list3             49
# 92     232                            item_id_click_hour_x             48
# 93     120                 category2_label_time_gap_before             48
# 94     215                               item_id_click_day             48
# 95     252                    category2_label_click_hour_y             48
# 96       2                                    item_city_id             47
# 97      94               user_item_id_first_click_interval             47
# 98     115                  context_page_id_time_gap_after             46
# 99       1                                   item_brand_id             46
# 100    226                       shop_star_level_click_day             45
# 101    221                  item_collected_level_click_day             44
# 102    167                        item_pv_level_smooth_CTR             44
# 103    243                    shop_star_level_click_hour_x             44
# 104    255               item_collected_level_click_hour_y             44
# 105     27                             item_property_list1             43
# 106    245                 user_occupation_id_click_hour_y             43
# 107    246                     user_age_level_click_hour_y             43
# 108     75                           item_id_click_day_min             43
# 109    227                            user_id_click_hour_x             43
# 110     89                        user_click_true_rank_day             42
# 111    195               shop_id_user_age_level_click_rate             42
# 112    199               item_id_user_age_level_click_rate             41
# 113    127                      item_id_time_gap_after_day             41
# 114     16                           shop_review_num_level             41
# 115     91                           time_gap_before_total             41
# 116    114                 context_page_id_time_gap_before             41
# 117    230                     user_gender_id_click_hour_x             41
# 118    249                            item_id_click_hour_y             40
# 119     85                   user_click_interval_first_day             40
# 120    258                            shop_id_click_hour_y             40
# 121    256                      item_pv_level_click_hour_y             40
# 122    225                 shop_review_num_level_click_day             40
# 123    240                    context_page_id_click_hour_x             40
# 124      9                                  user_age_level             39
# 125    250                      item_brand_id_click_hour_y             39
# 126     84                             user_last_click_day             39
# 127    222                         item_pv_level_click_day             38
# 128     70                          user_id_click_day_mean             38
# 129    253                   item_price_level_click_hour_y             38
# 130    239                      item_pv_level_click_hour_x             38
# 131    156                   user_occupation_id_smooth_CTR             37
# 132     97                          item_id_time_gap_after             37
# 133    257                    context_page_id_click_hour_y             37
# 134    259              shop_review_num_level_click_hour_y             36
# 135      5                            item_collected_level             36
# 136    242              shop_review_num_level_click_hour_x             36
# 137    123                     user_item_id_click_rank_day             35
# 138    206      item_price_level_user_gender_id_click_rate             35
# 139    164                     item_price_level_smooth_CTR             35
# 140    106               user_shop_id_first_click_interval             35
# 141    203         item_brand_id_user_age_level_click_rate             34
# 142     74                           item_id_click_day_max             33
# 143    231                    user_star_level_click_hour_x             33
# 144     76                    item_brand_id_click_day_mean             32
# 145    202         item_brand_id_user_gender_id_click_rate             32
# 146    142   user_context_page_id_first_click_interval_day             32
# 147    158                       user_gender_id_smooth_CTR             31
# 148    145              context_page_id_time_gap_after_day             31
# 149     68              user_category2_label_click_day_min             31
# 150     67             user_category2_label_click_day_mean             31
# 151    111                 user_context_page_id_click_rank             30
# 152    224                               shop_id_click_day             30
# 153    102                   item_brand_id_time_gap_before             30
# 154    212                        user_age_level_click_day             29
# 155     71                           user_id_click_day_max             29
# 156    229                     user_age_level_click_hour_x             29
# 157    219                      item_price_level_click_day             28
# 158    136           user_shop_id_first_click_interval_day             28
# 159     46                         user_item_id_click_hour             28
# 160     61               user_item_brand_id_click_day_mean             28
# 161    132               item_brand_id_time_gap_before_day             27
# 162    151              category2_label_time_gap_after_day             27
# 163    207      item_price_level_user_age_level_click_rate             27
# 164    130     user_item_brand_id_first_click_interval_day             26
# 165    103                    item_brand_id_time_gap_after             26
# 166    138                     shop_id_time_gap_before_day             26
# 167    113        user_context_page_id_last_click_interval             25
# 168     77                     item_brand_id_click_day_max             25
# 169    144             context_page_id_time_gap_before_day             25
# 170     78                     item_brand_id_click_day_min             24
# 171     73                          item_id_click_day_mean             24
# 172    190               user_id_category2_label_history_I             24
# 173     86                    user_click_interval_last_day             24
# 174     79                          shop_id_click_day_mean             24
# 175    125            user_item_id_last_click_interval_day             23
# 176    210                               user_id_click_day             23
# 177     54                 user_context_page_id_click_hour             23
# 178     36                     user_item_city_id_click_day             23
# 179    112       user_context_page_id_first_click_interval             22
# 180     14                                 context_page_id             21
# 181     18                                 shop_star_level             21
# 182     48                    user_item_city_id_click_hour             21
# 183    117                 user_category2_label_click_rank             21
# 184    211                    user_occupation_id_click_day             20
# 185    213                        user_gender_id_click_day             20
# 186    228                 user_occupation_id_click_hour_x             20
# 187    208  item_price_level_user_occupation_id_click_rate             20
# 188     82                             user_click_rank_day             20
# 189     64                     user_shop_id_click_day_mean             19
# 190     35                    user_item_brand_id_click_day             19
# 191     80                           shop_id_click_day_max             18
# 192    109                          shop_id_time_gap_after             18
# 193    108                         shop_id_time_gap_before             17
# 194     25                                 category2_label             17
# 195     26                             item_property_list0             16
# 196     99                   user_item_brand_id_click_rank             16
# 197    116            user_context_page_id_click_true_rank             16
# 198     72                           user_id_click_day_min             15
# 199    192              user_id_item_price_level_history_I             15
# 200    188                       user_id_shop_id_history_I             15
# 201    105                         user_shop_id_click_rank             14
# 202    129               user_item_brand_id_click_rank_day             14
# 203    135                     user_shop_id_click_rank_day             14
# 204     49                 user_category2_label_click_hour             14
# 205    153                                    property_sim             12
# 206     37                  user_category2_label_click_day             12
# 207     95                user_item_id_last_click_interval             12
# 208     39                 user_item_sales_level_click_day             12
# 209     51                user_item_sales_level_click_hour             11
# 210     40             user_item_collected_level_click_day             11
# 211     44            user_shop_review_num_level_click_day             11
# 212    272             user_category2_label_continue_click             11
# 213     38                 user_item_price_level_click_day             10
# 214    244                            user_id_click_hour_y             10
# 215    149    user_category2_label_last_click_interval_day             10
# 216     57                 user_shop_star_level_click_hour              9
# 217    133                item_brand_id_time_gap_after_day              8
# 218      6                                   item_pv_level              8
# 219     47                   user_item_brand_id_click_hour              8
# 220     52            user_item_collected_level_click_hour              8
# 221     42                  user_context_page_id_click_day              7
# 222     41                    user_item_pv_level_click_day              7
# 223    101          user_item_brand_id_last_click_interval              7
# 224    107                user_shop_id_last_click_interval              7
# 225     50                user_item_price_level_click_hour              6
# 226    184                       user_id_item_id_history_I              6
# 227     45                  user_shop_star_level_click_day              6
# 228     59                      user_item_id_click_day_min              6
# 229     69              user_category2_label_click_day_max              6
# 230    131      user_item_brand_id_last_click_interval_day              5
# 231    141             user_context_page_id_click_rank_day              5
# 232      3                                item_price_level              5
# 233     66                      user_shop_id_click_day_max              5
# 234     56           user_shop_review_num_level_click_hour              5
# 235     53                   user_item_pv_level_click_hour              4
# 236    152        user_category2_label_click_true_rank_day              4
# 237     60                      user_item_id_click_day_max              4
# 238     55                         user_shop_id_click_hour              4
# 239     63                user_item_brand_id_click_day_max              4
# 240    139                      shop_id_time_gap_after_day              4
# 241    147             user_category2_label_click_rank_day              4
# 242    143    user_context_page_id_last_click_interval_day              3
# 243     34                          user_item_id_click_day              2
# 244     10                              user_occupation_id              2
# 245     22                                             day              2
# 246    267                    user_item_brand_id_pre_click              2
# 247    268               user_item_brand_id_continue_click              2
# 248     83                            user_first_click_day              2
# 249    154                                      category_3              2
# 250    186                 user_id_item_brand_id_history_I              2
# 251     43                          user_shop_id_click_day              2
# 252     62                user_item_brand_id_click_day_min              2
# 253    270                     user_shop_id_continue_click              1
# 254    265                          user_item_id_pre_click              1
# 255      8                                  user_gender_id              1
# 256     65                      user_shop_id_click_day_min              1
# 257     98                    user_item_id_click_true_rank              1
# 258    146        user_context_page_id_click_true_rank_day              0
# 259    187                 user_id_item_brand_id_history_C              0
# 260    185                       user_id_item_id_history_C              0
# 261    189                       user_id_shop_id_history_C              0
# 262    128                user_item_id_click_true_rank_day              0
# 263    191               user_id_category2_label_history_C              0
# 264    193              user_id_item_price_level_history_C              0
# 265    140                user_shop_id_click_true_rank_day              0
# 266    266                     user_item_id_continue_click              0
# 267    110                    user_shop_id_click_true_rank              0
# 268    104              user_item_brand_id_click_true_rank              0
# 269    269                          user_shop_id_pre_click              0
# 270    134          user_item_brand_id_click_true_rank_day              0
# 271    271                  user_category2_label_pre_click              0
# 272    137            user_shop_id_last_click_interval_day              0

# %%
from sklearn.metrics import log_loss
from lightgbm import LGBMClassifier
import lightgbm as lgb

train_data = all_data[(all_data.day >= 19) & (all_data.day <= 23)]
test_data = all_data[all_data.day == 24]

lgb_clf = lgb.LGBMClassifier(objective='binary',

                             n_estimators=2000,
                             learning_rate=0.02,

                             max_depth=4,
                             num_leaves=30,
                             min_child_samples=100,
                             min_child_weight=1e-3,

                             colsample_bytree=1.0,
                             subsample=0.7,
                             subsample_freq=1,

                             reg_lambda=15,
                             min_split_gain=0.,
                             
                             max_bin=63,

                             n_jobs=-1,
                             silent=False,
                             
                             device='gpu',
                             gpu_use_dp=True,
                             )


lgb_clf.fit(train_data[features], train_data[target],
            eval_set=[(test_data[features], test_data[target])],
            early_stopping_rounds=100,
            verbose=50,
            feature_name=features,
            )

loss_train = log_loss(train_data[target],
                      lgb_clf.predict_proba(train_data[features]))
loss_test = log_loss(
    test_data[target], lgb_clf.predict_proba(test_data[features]))

loss_train, loss_test
# Out:
# Training until validation scores don't improve for 100 rounds.
# [50]	valid_0's binary_logloss: 0.241168
# [100]	valid_0's binary_logloss: 0.12659
# [150]	valid_0's binary_logloss: 0.0931066
# [200]	valid_0's binary_logloss: 0.0836024
# [250]	valid_0's binary_logloss: 0.0807791
# [300]	valid_0's binary_logloss: 0.0798235
# [350]	valid_0's binary_logloss: 0.0793766
# [400]	valid_0's binary_logloss: 0.079122
# [450]	valid_0's binary_logloss: 0.078976
# [500]	valid_0's binary_logloss: 0.0788777
# [550]	valid_0's binary_logloss: 0.0788011
# [600]	valid_0's binary_logloss: 0.0787411
# [650]	valid_0's binary_logloss: 0.0787169
# [700]	valid_0's binary_logloss: 0.0786801
# [750]	valid_0's binary_logloss: 0.078643
# [800]	valid_0's binary_logloss: 0.0786134
# [850]	valid_0's binary_logloss: 0.0786117
# [900]	valid_0's binary_logloss: 0.0785871
# [950]	valid_0's binary_logloss: 0.0785803
# [1000]	valid_0's binary_logloss: 0.0785894
# Early stopping, best iteration is:
# [932]	valid_0's binary_logloss: 0.0785674
# (0.080670807666239061, 0.078567408643239092)
